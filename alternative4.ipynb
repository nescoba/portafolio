# %% [markdown]
# <a href="https://colab.research.google.com/github/nescoba/portafolio/blob/main/alternative4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install itscalledsoccer
# Out:
# ...
#      |████████████████████████████████| 893 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 11.5 MB 28.5 MB/s
# ...
#      |████████████████████████████████| 61 kB 6.3 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
#   Attempting uninstall: CacheControl
#     Found existing installation: CacheControl 0.12.10
#     Uninstalling CacheControl-0.12.10:
#       Successfully uninstalled CacheControl-0.12.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.25.1 which is incompatible.
# ...

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline 
sns.set()

# %%
from itscalledsoccer.client import AmericanSoccerAnalysis

asa_client = AmericanSoccerAnalysis()
# Out:
# Gathering all players
# Gathering all teams
# Gathering all stadia
# Gathering all managers
# Gathering all referees
# Finished initializing client

# %%
import statsmodels.api as sm
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
games = asa_client.get_game_xgoals(leagues='mls')
games
# Out:
#         game_id            date_time_utc home_team_id  home_goals  \
# 0    2lqRoy3JQr  2022-03-13 23:00:00 UTC   a2lqRX2Mr0           0
# 1    9Yqd3nDL5v  2022-03-13 20:30:00 UTC   KAqBN0Vqbg           2
# 2    KXMeBo1r56  2022-03-13 03:00:00 UTC   WBLMvYAQxe           1
# 3    EGMPOxJVQa  2022-03-13 02:00:00 UTC   pzeQZ6xQKw           2
# 4    gjMNGxZ05K  2022-03-13 01:30:00 UTC   mKAqBBmqbg           2
# ..          ...                      ...          ...         ...
# 443  xW5pyO8Jqg  2013-03-03 03:30:00 UTC   jYQJ19EqGR           0
# 444  KPqjK3VYQ6  2013-03-03 01:30:00 UTC   mKAqBBmqbg           1
# 445  kRQaolgj5K  2013-03-03 01:00:00 UTC   YgOMngl5wN           1
# 446  9vQ2ZGnmQK  2013-03-02 23:30:00 UTC   lgpMOvnQzy           1
# 447  NPqxxL8Xq9  2013-03-02 21:00:00 UTC   9z5k7Yg5A3           1
#
#      home_team_xgoals  home_player_xgoals away_team_id  away_goals  \
# 0              3.2145              3.2421   kRQand1MKZ           1
# ...

# %%
teams = asa_client.get_teams(leagues='mls')
teams
# Out:
#        team_id               team_name team_short_name team_abbreviation  \
# 0   0KPqjA456v    San Jose Earthquakes        San Jose               SJE
# 1   19vQ2095K6  New England Revolution     New England               NER
# 2   4wM42l4qjB              Chivas USA          Chivas               CHV
# 3   9z5k7Yg5A3      Philadelphia Union    Philadelphia               PHI
# 4   a2lqR4JMr0          Real Salt Lake       Salt Lake               RSL
# 5   a2lqRX2Mr0      New York Red Bulls        New York              NYRB
# 6   APk5LGOMOW             CF Montréal        Montréal               MTL
# 7   EKXMeX3Q64             D.C. United     D.C. United               DCU
# 8   eVq3ya6MWO          Los Angeles FC  Los Angeles FC              LAFC
# 9   gpMOLwl5zy               Austin FC          Austin               ATX
# 10  jYQJ19EqGR     Seattle Sounders FC         Seattle               SEA
# 11  jYQJ8EW5GR         Orlando City SC    Orlando City               ORL
# ...

# %%
def construct_time_series_date(team_id, date, seasons):

    # print(seasons)
    seasons.loc[:, 'date_formated'] = pd.to_datetime(seasons['date_time_utc'])
    seasons = seasons[seasons['date_formated'] < date]

    seasons_team = seasons[(seasons['home_team_id']==team_id) | (seasons['away_team_id']==team_id)]
    team_home = seasons_team[seasons_team['home_team_id']==team_id]
    team_away = seasons_team[seasons_team['away_team_id']==team_id]

    

    team_home.loc[:,'teamxgoals'] = team_home['home_team_xgoals']
    team_away.loc[:,'teamxgoals'] = team_away['away_team_xgoals']

    team_home.loc[:,'teamgoals'] = team_home['home_goals']
    team_away.loc[:,'teamgoals'] = team_away['away_goals']

    team_home.loc[:,'oppoxgoals'] = team_home['away_team_xgoals']
    team_away.loc[:,'oppoxgoals'] = team_away['home_team_xgoals']

    team_home.loc[:,'oppogoals'] = team_home['away_goals']
    team_away.loc[:,'oppogoals'] = team_away['home_goals']

    if len(team_home)>0:
        team_home.loc[:, 'home'] = 1
    else:
        team_home.loc[:, 'home'] = team_home['away_goals']

    if len(team_away)>0:
        team_away.loc[:, 'home'] = 0
    else:
        team_away.loc[:, 'home'] = team_away['away_goals']

    team_home_red = team_home.loc[:, ['teamgoals', 'teamxgoals', 'oppoxgoals', 'oppogoals', 'date_formated', 'home']]
    team_away_red = team_away.loc[:, ['teamgoals', 'teamxgoals', 'oppoxgoals', 'oppogoals', 'date_formated', 'home']]

    team_red = pd.merge(team_home_red, team_away_red, how='outer')

    team_red = team_red.sort_values(by='date_formated')

    return team_red

# %%
data = construct_time_series_date('Vj58weDM8n', pd.to_datetime('2022-03-18 00:00 UTC'), games)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %%
data.groupby('home')['teamxgoals'].mean()
# Out:
# home
# 0    1.239756
# 1    1.819036
# Name: teamxgoals, dtype: float64

# %%
data.groupby('home')['oppoxgoals'].mean()
# Out:
# home
# 0    1.501869
# 1    1.194739
# Name: oppoxgoals, dtype: float64

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(data['teamgoals'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -15.608878
# p-value: 0.000000

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(data['teamxgoals'])

# %%
plot_pacf(data['teamxgoals'])

# %%
plot_acf(data['oppoxgoals'])

# %%
plot_pacf(data['oppoxgoals'])

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA(data['teamxgoals'], order=(5,0,1), exog=data['home'])
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                               ARMA Model Results
# ...
# Dep. Variable:             teamxgoals   No. Observations:                  245
# Model:                     ARMA(5, 1)   Log Likelihood                -258.850
# Method:                       css-mle   S.D. of innovations              0.696
# Date:                Fri, 18 Mar 2022   AIC                            535.700
# Time:                        13:22:41   BIC                            567.211
# Sample:                             0   HQIC                           548.389
#
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
model = ARIMA(data['teamxgoals'], order=(1,0,1), exog=data['home'])
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                               ARMA Model Results
# ...
# Dep. Variable:             teamxgoals   No. Observations:                  245
# Model:                     ARMA(1, 1)   Log Likelihood                -260.528
# Method:                       css-mle   S.D. of innovations              0.701
# Date:                Fri, 18 Mar 2022   AIC                            531.055
# Time:                        13:23:20   BIC                            548.562
# Sample:                             0   HQIC                           538.105
#
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
model = ARIMA(data['teamxgoals'], order=(1,0,0), exog=data['home'])
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:             teamxgoals   No. Observations:                  245
# Model:                     ARMA(1, 0)   Log Likelihood                -260.761
# Method:                       css-mle   S.D. of innovations              0.701
# Date:                Fri, 18 Mar 2022   AIC                            529.522
# Time:                        13:24:28   BIC                            543.527
# Sample:                             0   HQIC                           535.162
#
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.2374      0.064     19.190      0.000       1.111       1.364
# home                 0.5839      0.088      6.604      0.000       0.411       0.757
# ar.L1.teamxgoals     0.0554      0.064      0.867      0.387      -0.070       0.181
# ...

# %%
model = ARIMA(data['teamxgoals'], order=(5,1,1), exog=data['home'])
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ...
# Dep. Variable:           D.teamxgoals   No. Observations:                  244
# Model:                 ARIMA(5, 1, 1)   Log Likelihood                -277.242
# Method:                       css-mle   S.D. of innovations              0.745
# Date:                Fri, 18 Mar 2022   AIC                            572.484
# Time:                        13:26:39   BIC                            603.958
# Sample:                             1   HQIC                           585.160
#
# ...

# %%
model = ARIMA(data['teamxgoals'], order=(0,1,1), exog=data['home'])
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ...
# Dep. Variable:           D.teamxgoals   No. Observations:                  244
# Model:                 ARIMA(0, 1, 1)   Log Likelihood                -279.390
# Method:                       css-mle   S.D. of innovations              0.752
# Date:                Fri, 18 Mar 2022   AIC                            566.781
# Time:                        13:27:18   BIC                            580.769
# Sample:                             1   HQIC                           572.415
#
# ...

# %%
model = ARIMA(data['teamxgoals'], order=(0,1,2), exog=data['home'])
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ...
# Dep. Variable:           D.teamxgoals   No. Observations:                  244
# Model:                 ARIMA(0, 1, 2)   Log Likelihood                -279.383
# Method:                       css-mle   S.D. of innovations              0.752
# Date:                Fri, 18 Mar 2022   AIC                            568.767
# Time:                        13:28:04   BIC                            586.253
# Sample:                             1   HQIC                           575.809
#
# ...

# %%
model = ARIMA(data['teamxgoals'], order=(0,1,1), exog=data['home'])
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ...
# Dep. Variable:           D.teamxgoals   No. Observations:                  244
# Model:                 ARIMA(0, 1, 1)   Log Likelihood                -279.390
# Method:                       css-mle   S.D. of innovations              0.752
# Date:                Fri, 18 Mar 2022   AIC                            566.781
# Time:                        13:28:19   BIC                            580.769
# Sample:                             1   HQIC                           572.415
#
# ...

# %%
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
model_fit.plot_predict(dynamic=False)
plt.show()

# %%
model_fit.fittedvalues
# Out:
# 120    0.069137
# 243   -1.244506
# 119    0.908333
# 242    0.304825
# 118   -0.021802
#          ...
# 124    0.248574
# 123    0.082278
# 122    0.511505
# 121    0.689206
# 0     -0.172462
# Length: 244, dtype: float64

# %%
plt.plot(data['date_formated'], data['teamxgoals'])
plt.plot(data['date_formated'][1:], model_fit.fittedvalues)

# %%
plt.plot(data['date_formated'], data['teamxgoals'])
plt.plot(data['date_formated'][1:], np.cumsum(model_fit.fittedvalues))

# %%
plt.hist(model_fit.resid, bins=30)
# Out:
# (array([ 2.,  3.,  3.,  9., 13., 15., 18., 14., 20., 16., 21., 20., 13.,
#         13., 10.,  9.,  7.,  2.,  9.,  5.,  3.,  3.,  4.,  3.,  2.,  1.,
#          0.,  1.,  2.,  3.]),
#  array([-1.41820024e+00, -1.28942723e+00, -1.16065423e+00, -1.03188122e+00,
#         -9.03108216e-01, -7.74335210e-01, -6.45562203e-01, -5.16789197e-01,
#         -3.88016191e-01, -2.59243185e-01, -1.30470179e-01, -1.69717244e-03,
#          1.27075834e-01,  2.55848840e-01,  3.84621846e-01,  5.13394852e-01,
#          6.42167859e-01,  7.70940865e-01,  8.99713871e-01,  1.02848688e+00,
#          1.15725988e+00,  1.28603289e+00,  1.41480590e+00,  1.54357890e+00,
#          1.67235191e+00,  1.80112491e+00,  1.92989792e+00,  2.05867093e+00,
#          2.18744393e+00,  2.31621694e+00,  2.44498995e+00]),
#  <a list of 30 Patch objects>)

# %%
plt.plot(data['date_formated'][1:], np.cumsum(model_fit.predict()))

# %%
model = ARIMA(data['teamxgoals'], order=(3,0,3), exog=data['home'])
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                               ARMA Model Results
# ...
# Dep. Variable:             teamxgoals   No. Observations:                  245
# Model:                     ARMA(3, 3)   Log Likelihood                -257.296
# Method:                       css-mle   S.D. of innovations              0.688
# Date:                Fri, 18 Mar 2022   AIC                            532.592
# Time:                        15:14:06   BIC                            564.104
# Sample:                             0   HQIC                           545.282
#
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
model = ARIMA(data['teamxgoals'], order=(0,0,1), exog=data['home'])
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:             teamxgoals   No. Observations:                  245
# Model:                     ARMA(0, 1)   Log Likelihood                -260.739
# Method:                       css-mle   S.D. of innovations              0.701
# Date:                Fri, 18 Mar 2022   AIC                            529.477
# Time:                        15:14:46   BIC                            543.482
# Sample:                             0   HQIC                           535.117
#
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.2372      0.064     19.194      0.000       1.111       1.364
# home                 0.5842      0.088      6.613      0.000       0.411       0.757
# ma.L1.teamxgoals     0.0589      0.066      0.891      0.374      -0.071       0.189
# ...

# %%
model = ARIMA(data['teamxgoals'], order=(0,0,3), exog=data['home'])
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:             teamxgoals   No. Observations:                  245
# Model:                     ARMA(0, 3)   Log Likelihood                -260.378
# Method:                       css-mle   S.D. of innovations              0.700
# Date:                Fri, 18 Mar 2022   AIC                            532.757
# Time:                        15:15:17   BIC                            553.765
# Sample:                             0   HQIC                           541.217
#
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.2392      0.065     19.150      0.000       1.112       1.366
# home                 0.5798      0.088      6.557      0.000       0.407       0.753
# ma.L1.teamxgoals     0.0574      0.064      0.895      0.372      -0.068       0.183
# ...

# %%
model = ARIMA(data['teamxgoals'], order=(0,1,1), exog=data['home'])
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ...
# Dep. Variable:           D.teamxgoals   No. Observations:                  244
# Model:                 ARIMA(0, 1, 1)   Log Likelihood                -279.390
# Method:                       css-mle   S.D. of innovations              0.752
# Date:                Fri, 18 Mar 2022   AIC                            566.781
# Time:                        15:24:03   BIC                            580.769
# Sample:                             1   HQIC                           572.415
#
# ...

# %%
plt.rcParams["figure.figsize"] = (20,3)
plt.plot(data['date_formated'], data['teamxgoals'].diff())
plt.plot(data['date_formated'][1:], model_fit.fittedvalues)

# %%
model = ARIMA(data['oppoxgoals'], order=(0,1,1), exog=data['home'])
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:           D.oppoxgoals   No. Observations:                  244
# Model:                 ARIMA(0, 1, 1)   Log Likelihood                -265.211
# Method:                       css-mle   S.D. of innovations              0.709
# Date:                Fri, 18 Mar 2022   AIC                            538.422
# Time:                        15:41:17   BIC                            552.410
# Sample:                             1   HQIC                           544.055
#
# ...
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.0511      0.035      1.477      0.141      -0.017       0.119
# home                  -0.1081      0.069     -1.562      0.120      -0.244       0.028
# ma.L1.D.oppoxgoals    -1.0000      0.017    -58.163      0.000      -1.034      -0.966
# ...

# %%
plt.rcParams["figure.figsize"] = (20,3)
plt.plot(data['date_formated'], data['oppoxgoals'].diff())
plt.plot(data['date_formated'][1:], model_fit.fittedvalues)

# %%
model_fit.forecast(exog=np.array([1]))[0][0]
# Out:
# 1.1074289806677897

# %% [markdown]
# ---

# %%
data.loc[:, 'teamxgoalsCat'] = pd.cut(data['teamxgoals'], bins=30)
data
# Out:
#      teamgoals  teamxgoals  oppoxgoals  oppogoals             date_formated  \
# 244          1      0.5261      0.5973          1 2015-03-08 21:00:00+00:00
# 120          2      2.9509      1.7539          0 2015-03-15 21:00:00+00:00
# 243          0      0.4476      1.1147          0 2015-03-21 20:00:00+00:00
# 119          0      0.8606      1.1757          1 2015-03-28 23:00:00+00:00
# 242          1      1.2791      1.8125          2 2015-04-11 20:00:00+00:00
# ..         ...         ...         ...        ...                       ...
# 124          2      1.4296      0.5437          0 2021-12-05 20:00:00+00:00
# 123          1      0.9313      1.4137          1 2021-12-11 20:00:00+00:00
# 122          0      0.6838      1.4804          1 2022-02-27 22:00:00+00:00
# 121          0      1.6156      0.6807          0 2022-03-05 23:00:00+00:00
# 0            4      2.1512      2.2814          1 2022-03-12 18:00:00+00:00
#
#      home   teamxgoalsCat
# 244     0  (0.487, 0.618]
# ...

# %%
data.groupby('teamxgoalsCat')['teamxgoals'].describe()
# Out:
#                 count      mean       std     min       25%      50%  \
# teamxgoalsCat
# (0.221, 0.356]    4.0  0.274775  0.051980  0.2251  0.237400  0.26720
# (0.356, 0.487]    6.0  0.430917  0.038406  0.3624  0.423100  0.43655
# (0.487, 0.618]   11.0  0.557518  0.034870  0.5071  0.533100  0.55710
# (0.618, 0.749]   11.0  0.686845  0.037771  0.6213  0.670500  0.69310
# (0.749, 0.88]    16.0  0.797006  0.040504  0.7523  0.761800  0.79100
# (0.88, 1.011]    22.0  0.950936  0.034301  0.8911  0.928525  0.95590
# (1.011, 1.143]   17.0  1.081865  0.043131  1.0130  1.047100  1.07620
# (1.143, 1.274]   17.0  1.227476  0.032027  1.1590  1.208900  1.23390
# (1.274, 1.405]   17.0  1.341153  0.042496  1.2738  1.298400  1.35710
# (1.405, 1.536]   28.0  1.466921  0.035623  1.4110  1.432125  1.46320
# (1.536, 1.667]    8.0  1.629675  0.024719  1.5871  1.617625  1.62540
# (1.667, 1.798]   12.0  1.735258  0.038317  1.6825  1.696200  1.74635
# ...

# %%
data.loc[:, 'teamxgoalsPred'] = np.random.poisson(data['teamxgoals'])
data
# Out:
#      teamgoals  teamxgoals  oppoxgoals  oppogoals             date_formated  \
# 244          1      0.5261      0.5973          1 2015-03-08 21:00:00+00:00
# 120          2      2.9509      1.7539          0 2015-03-15 21:00:00+00:00
# 243          0      0.4476      1.1147          0 2015-03-21 20:00:00+00:00
# 119          0      0.8606      1.1757          1 2015-03-28 23:00:00+00:00
# 242          1      1.2791      1.8125          2 2015-04-11 20:00:00+00:00
# ..         ...         ...         ...        ...                       ...
# 124          2      1.4296      0.5437          0 2021-12-05 20:00:00+00:00
# 123          1      0.9313      1.4137          1 2021-12-11 20:00:00+00:00
# 122          0      0.6838      1.4804          1 2022-02-27 22:00:00+00:00
# 121          0      1.6156      0.6807          0 2022-03-05 23:00:00+00:00
# 0            4      2.1512      2.2814          1 2022-03-12 18:00:00+00:00
#
#      home   teamxgoalsCat  teamxgoalsPred
# ...

# %%
plt.hist(data['teamgoals'] - data['teamxgoalsPred'], bins=[-2.5, -1.5, 0.5, 1.5, 2.5, 3.5, 4.5])
# Out:
# (array([ 24., 106.,  62.,  26.,  11.,   1.]),
#  array([-2.5, -1.5,  0.5,  1.5,  2.5,  3.5,  4.5]),
#  <a list of 6 Patch objects>)

# %%
data.groupby('teamxgoalsCat')['teamxgoalsPred'].describe()
# Out:
#                 count      mean       std  min   25%  50%   75%  max
# teamxgoalsCat
# (0.221, 0.356]    4.0  0.250000  0.500000  0.0  0.00  0.0  0.25  1.0
# (0.356, 0.487]    6.0  0.666667  0.816497  0.0  0.00  0.5  1.00  2.0
# (0.487, 0.618]   11.0  0.909091  0.943880  0.0  0.00  1.0  2.00  2.0
# (0.618, 0.749]   11.0  0.818182  0.981650  0.0  0.00  1.0  1.00  3.0
# (0.749, 0.88]    16.0  0.687500  0.793200  0.0  0.00  0.5  1.00  2.0
# (0.88, 1.011]    22.0  0.954545  0.898532  0.0  0.00  1.0  1.00  3.0
# (1.011, 1.143]   17.0  1.235294  0.903425  0.0  1.00  1.0  2.00  3.0
# (1.143, 1.274]   17.0  1.117647  0.927520  0.0  0.00  1.0  2.00  3.0
# (1.274, 1.405]   17.0  1.058824  1.028992  0.0  0.00  1.0  2.00  3.0
# (1.405, 1.536]   28.0  1.107143  0.785955  0.0  0.75  1.0  2.00  2.0
# (1.536, 1.667]    8.0  1.875000  1.125992  1.0  1.00  1.5  2.25  4.0
# (1.667, 1.798]   12.0  1.750000  1.422226  0.0  0.75  2.0  2.25  4.0
# ...

# %%
data.loc[:, 'teamxgoalsPred'] = np.random.binomial()
data

# %% [markdown]
# ----

# %%
import math
def round_randomly(h):
    return np.random.choice([math.floor(h), math.ceil(h)], p=[math.ceil(h)-h, 1 - (math.ceil(h)-h)])
    # return np.random.poisson(h)
round_randomly(3.4)
# Out:
# 3

# %%
data.loc[:, 'teamxgoalsPred'] = data['teamxgoals'].apply(round_randomly)
data
# Out:
#      teamgoals  teamxgoals  oppoxgoals  oppogoals             date_formated  \
# 244          1      0.5261      0.5973          1 2015-03-08 21:00:00+00:00
# 120          2      2.9509      1.7539          0 2015-03-15 21:00:00+00:00
# 243          0      0.4476      1.1147          0 2015-03-21 20:00:00+00:00
# 119          0      0.8606      1.1757          1 2015-03-28 23:00:00+00:00
# 242          1      1.2791      1.8125          2 2015-04-11 20:00:00+00:00
# ..         ...         ...         ...        ...                       ...
# 124          2      1.4296      0.5437          0 2021-12-05 20:00:00+00:00
# 123          1      0.9313      1.4137          1 2021-12-11 20:00:00+00:00
# 122          0      0.6838      1.4804          1 2022-02-27 22:00:00+00:00
# 121          0      1.6156      0.6807          0 2022-03-05 23:00:00+00:00
# 0            4      2.1512      2.2814          1 2022-03-12 18:00:00+00:00
#
#      home   teamxgoalsCat  teamxgoalsPred
# ...

# %%
plt.hist(data['teamgoals'] - data['teamxgoalsPred'], bins=[-2.5, -1.5, 0.5, 1.5, 2.5, 3.5, 4.5])
# Out:
# (array([ 10., 156.,  55.,  18.,   5.,   1.]),
#  array([-2.5, -1.5,  0.5,  1.5,  2.5,  3.5,  4.5]),
#  <a list of 6 Patch objects>)

# %%
data.groupby('teamxgoalsCat')['teamxgoalsPred'].describe()
# Out:
#                 count      mean       std  min   25%  50%   75%  max
# teamxgoalsCat
# (0.221, 0.356]    4.0  0.000000  0.000000  0.0  0.00  0.0  0.00  0.0
# (0.356, 0.487]    6.0  0.333333  0.516398  0.0  0.00  0.0  0.75  1.0
# (0.487, 0.618]   11.0  0.727273  0.467099  0.0  0.50  1.0  1.00  1.0
# (0.618, 0.749]   11.0  0.818182  0.404520  0.0  1.00  1.0  1.00  1.0
# (0.749, 0.88]    16.0  0.875000  0.341565  0.0  1.00  1.0  1.00  1.0
# (0.88, 1.011]    22.0  0.909091  0.294245  0.0  1.00  1.0  1.00  1.0
# (1.011, 1.143]   17.0  1.058824  0.242536  1.0  1.00  1.0  1.00  2.0
# (1.143, 1.274]   17.0  1.294118  0.469668  1.0  1.00  1.0  2.00  2.0
# (1.274, 1.405]   17.0  1.411765  0.507300  1.0  1.00  1.0  2.00  2.0
# (1.405, 1.536]   28.0  1.285714  0.460044  1.0  1.00  1.0  2.00  2.0
# (1.536, 1.667]    8.0  1.750000  0.462910  1.0  1.75  2.0  2.00  2.0
# (1.667, 1.798]   12.0  1.750000  0.452267  1.0  1.75  2.0  2.00  2.0
# ...

# %% [markdown]
# ----

# %%
def project_result(home_id, away_id, games, date):
    data_home = construct_time_series_date(home_id, date, games)
    data_away = construct_time_series_date(away_id, date, games)

    try:
        model_home = ARIMA(data_home['teamxgoals'], order=(0,1,1), exog=data_home['home'])
        model_home_fit = model_home.fit(disp=0)

        model_away = ARIMA(data_away['teamxgoals'], order=(0,1,1), exog=data_away['home'])
        model_away_fit = model_away.fit(disp=0)

        home_xgoals = model_home_fit.forecast(1, exog=np.array([1]))[0][0]
        away_xgoals = model_away_fit.forecast(1, exog=np.array([0]))[0][0]

    except:
        home_xgoals = 1
        away_xgoals = 1

    n_home = 0
    n_draw = 0
    n_away = 0

    N = 10000

    for n in range(N):
        home_goals = round_randomly(home_xgoals)
        away_goals = round_randomly(away_xgoals)

        if home_goals > away_goals:
            n_home += 1
        elif home_goals == away_goals:
            n_draw += 1 
        else:
            n_away += 1 

    return (n_home/N , n_draw/N, n_away/N)

# %%
teams
# Out:
#        team_id               team_name team_short_name team_abbreviation  \
# 0   0KPqjA456v    San Jose Earthquakes        San Jose               SJE
# 1   19vQ2095K6  New England Revolution     New England               NER
# 2   4wM42l4qjB              Chivas USA          Chivas               CHV
# 3   9z5k7Yg5A3      Philadelphia Union    Philadelphia               PHI
# 4   a2lqR4JMr0          Real Salt Lake       Salt Lake               RSL
# 5   a2lqRX2Mr0      New York Red Bulls        New York              NYRB
# 6   APk5LGOMOW             CF Montréal        Montréal               MTL
# 7   EKXMeX3Q64             D.C. United     D.C. United               DCU
# 8   eVq3ya6MWO          Los Angeles FC  Los Angeles FC              LAFC
# 9   gpMOLwl5zy               Austin FC          Austin               ATX
# 10  jYQJ19EqGR     Seattle Sounders FC         Seattle               SEA
# 11  jYQJ8EW5GR         Orlando City SC    Orlando City               ORL
# ...

# %%
project_result('Z2vQ1xlqrA', 'zeQZkL1MKw', games, '2022-03-18 00:00 UTC')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ...

# %% [markdown]
# ----

# %%
def probs_game_from_id(matchid, all_games):

    # print(all_games)
    # print(matchid)
   
    homeid = all_games.loc[all_games['game_id']==matchid, 'home_team_id'].values[0]

    awayid = all_games.loc[all_games['game_id']==matchid, 'away_team_id'].values[0]

    date = pd.to_datetime(all_games.loc[all_games['game_id']==matchid, 'date_time_utc'].values[0])

    print(date)

    return project_result(homeid, awayid, all_games, date)

# %%
games_rec = games[:200]
games_rec
# Out:
#         game_id            date_time_utc home_team_id  home_goals  \
# 0    2lqRoy3JQr  2022-03-13 23:00:00 UTC   a2lqRX2Mr0           0
# 1    9Yqd3nDL5v  2022-03-13 20:30:00 UTC   KAqBN0Vqbg           2
# 2    KXMeBo1r56  2022-03-13 03:00:00 UTC   WBLMvYAQxe           1
# 3    EGMPOxJVQa  2022-03-13 02:00:00 UTC   pzeQZ6xQKw           2
# 4    gjMNGxZ05K  2022-03-13 01:30:00 UTC   mKAqBBmqbg           2
# ..          ...                      ...          ...         ...
# 195  xW5pXPR05g  2021-09-16 02:00:00 UTC   WBLMvYAQxe           2
# 196  KPqjAngN56  2021-09-16 01:00:00 UTC   gpMOLwl5zy           1
# 197  aDQ0r1XE5E  2021-09-16 00:30:00 UTC   Z2vQ1xlqrA           4
# 198  NPqxXl7Yq9  2021-09-15 23:30:00 UTC   EKXMeX3Q64           3
# 199  XVqK8kVNQ0  2021-09-15 23:30:00 UTC   jYQJ8EW5GR           2
#
#      home_team_xgoals  home_player_xgoals away_team_id  away_goals  \
# 0              3.2145              3.2421   kRQand1MKZ           1
# ...

# %%
games_rec.loc[:, 'probs'] = games_rec['game_id'].apply(probs_game_from_id, all_games=games)
games_rec
# Out:
# 2022-03-13 23:00:00+00:00
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ...

# %%
games_rec.loc[:, 'NH'] = games_rec['probs'].apply(lambda x: x[0])
games_rec.loc[:, 'ND'] = games_rec['probs'].apply(lambda x: x[1])
games_rec.loc[:, 'NA'] = games_rec['probs'].apply(lambda x: x[2])

games_rec
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         game_id            date_time_utc home_team_id  home_goals  \
# 0    2lqRoy3JQr  2022-03-13 23:00:00 UTC   a2lqRX2Mr0           0
# 1    9Yqd3nDL5v  2022-03-13 20:30:00 UTC   KAqBN0Vqbg           2
# 2    KXMeBo1r56  2022-03-13 03:00:00 UTC   WBLMvYAQxe           1
# 3    EGMPOxJVQa  2022-03-13 02:00:00 UTC   pzeQZ6xQKw           2
# 4    gjMNGxZ05K  2022-03-13 01:30:00 UTC   mKAqBBmqbg           2
# ..          ...                      ...          ...         ...
# 195  xW5pXPR05g  2021-09-16 02:00:00 UTC   WBLMvYAQxe           2
# ...

# %%
games_rec.loc[:, 'NHCat'] = pd.cut(games_rec['NH'], bins=10)
games_rec.loc[:, 'NDCat'] = pd.cut(games_rec['ND'], bins=10)
games_rec.loc[:, 'NACat'] = pd.cut(games_rec['NA'], bins=10)
games_rec
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#         game_id            date_time_utc home_team_id  home_goals  \
# 0    2lqRoy3JQr  2022-03-13 23:00:00 UTC   a2lqRX2Mr0           0
# 1    9Yqd3nDL5v  2022-03-13 20:30:00 UTC   KAqBN0Vqbg           2
# 2    KXMeBo1r56  2022-03-13 03:00:00 UTC   WBLMvYAQxe           1
# 3    EGMPOxJVQa  2022-03-13 02:00:00 UTC   pzeQZ6xQKw           2
# 4    gjMNGxZ05K  2022-03-13 01:30:00 UTC   mKAqBBmqbg           2
# ..          ...                      ...          ...         ...
# 195  xW5pXPR05g  2021-09-16 02:00:00 UTC   WBLMvYAQxe           2
# ...

# %%
for (category, group) in games_rec.groupby('NHCat'):
    print((category.mid, len(group[group['final_score_difference']>0])/len(group), len(group)))
# Out:
# (0.0357885, 0.3870967741935484, 31)
# (0.10865, 0.3888888888888889, 18)
# (0.181, 0.4857142857142857, 35)
# (0.253, 0.48717948717948717, 39)
# (0.32499999999999996, 0.5909090909090909, 22)
# (0.39749999999999996, 0.4444444444444444, 27)
# (0.47, 0.6923076923076923, 13)
# (0.542, 0.42857142857142855, 7)
# (0.614, 0.8, 5)
# (0.6865, 0.3333333333333333, 3)

# %%
for (category, group) in games_rec.groupby('NDCat'):
    print((category.mid, len(group[group['final_score_difference']==0])/len(group), len(group)))
# Out:
# (0.226, 0.0, 1)
# (0.3075, 0.1, 10)
# (0.389, 0.16666666666666666, 18)
# (0.47050000000000003, 0.23170731707317074, 82)
# (0.552, 0.3269230769230769, 52)
# (0.6335, 0.3333333333333333, 21)
# (0.7150000000000001, 0.2857142857142857, 7)
# (0.7965, 0.3333333333333333, 3)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-154-c7803644e1b2> in <module>()
#       1 for (category, group) in games_rec.groupby('NDCat'):
# ----> 2     print((category.mid, len(group[group['final_score_difference']==0])/len(group), len(group)))
#
# ZeroDivisionError: division by zero

# %%
for (category, group) in games_rec.groupby('NACat'):
    print((category.mid, len(group[group['final_score_difference']<0])/len(group), len(group)))
# Out:
# (0.040293, 0.3023255813953488, 43)
# (0.1222, 0.23404255319148937, 47)
# (0.20350000000000001, 0.21052631578947367, 38)
# (0.28500000000000003, 0.0967741935483871, 31)
# (0.3665, 0.4444444444444444, 18)
# (0.44799999999999995, 0.2, 5)
# (0.5295, 0.3333333333333333, 6)
# (0.611, 0.2857142857142857, 7)
# (0.6925, 1.0, 4)
# (0.7735, 1.0, 1)

# %%
def choose_winner(probs):
    try:
        new_probs = [probs[0]+0.3, probs[1]-0.3, probs[2]]
        return np.random.choice(['H', 'D', 'A'], p=new_probs)[0]
    except:
        return np.random.choice(['H', 'D', 'A'], p=probs)[0]
choose_winner((.1, .1, .8))
# Out:
# 'A'

# %%
games_rec.loc[:, 'chosen_winner'] = games_rec['probs'].apply(choose_winner)

def decide_winner(diff):
    if diff > 0:
        return 'H'
    elif diff == 0:
        return 'D'
    else:
        return 'A'

games_rec.loc[:, 'winner'] = games_rec['final_score_difference'].apply(decide_winner)
    
from sklearn.metrics import accuracy_score

accuracy_score(games_rec['winner'], games_rec['chosen_winner'])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# 0.4

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(games_rec['winner'], games_rec['chosen_winner'],labels=['H', 'D', 'A'])
# Out:
# array([[56, 21, 20],
#        [27,  8, 15],
#        [24, 13, 16]])
