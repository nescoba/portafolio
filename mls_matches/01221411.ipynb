# %% [markdown]
# # Can we predict the result of a soccer match without looking at the score?

# %% [markdown]
# - Usual imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime 

# %matplotlib inline 
sns.set()

# %% [markdown]
# - loading data

# %%
df = pd.read_csv('matches.csv')
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (11,14,50,102,123,125,129,131,133,135,137,139,141,143,145,147,149,157,158,160,161,163,165,167,169,171,173,184,186,187,205,206) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    id         home         away       date  year time (utc) attendance  \
# 0 NaN  New England     San Jose  7/31/1996  1996        NaN     12,871
# 1 NaN       Dallas     Colorado  6/15/1996  1996        NaN      9,704
# 2 NaN     Colorado  D.C. United  8/29/1996  1996        NaN      6,368
# 3 NaN    LA Galaxy  New England   8/8/1996  1996        NaN     10,251
# 4 NaN  New England  D.C. United  7/20/1996  1996        NaN     18,347
#
#                venue    league part_of_competition  ... away_offsides  \
# 0    Foxboro Stadium  1996 MLS      Regular Season  ...           NaN
# 1        Cotton Bowl  1996 MLS      Regular Season  ...           NaN
# 2  Mile High Stadium  1996 MLS      Regular Season  ...           NaN
# 3          Rose Bowl  1996 MLS      Regular Season  ...           NaN
# 4    Foxboro Stadium  1996 MLS      Regular Season  ...           NaN
#
#   home_wonCorners  away_wonCorners  home_saves away_saves away_bench_14_num  \
# 0             NaN              NaN         NaN        NaN               NaN
# 1             NaN              NaN         NaN        NaN               NaN
# 2             NaN              NaN         NaN        NaN               NaN
# 3             NaN              NaN         NaN        NaN               NaN
# 4             NaN              NaN         NaN        NaN               NaN
#
#   away_bench_14 away_bench_14_minute home_formation  away_formation
# 0           NaN                  NaN            NaN             NaN
# 1           NaN                  NaN            NaN             NaN
# 2           NaN                  NaN            NaN             NaN
# 3           NaN                  NaN            NaN             NaN
# 4           NaN                  NaN            NaN             NaN
#
# [5 rows x 209 columns]

# %% [markdown]
# - Selecting the columns we are going to use

# %%
list_of_columns =[
 'home',
 'away',
 'date',
 'league',
 'part_of_competition',
 'game_status',
 'home_score',
 'away_score', 
 'home_possessionPct',
 'away_possessionPct',
 'home_shotsSummary',
 'away_shotsSummary',
 'home_foulsCommitted',
 'away_foulsCommitted',
 'home_yellowCards',
 'away_yellowCards',
 'home_redCards',
 'away_redCards',
 'home_offsides',
 'away_offsides',
 'home_wonCorners',
 'away_wonCorners',
 'home_saves',
 'away_saves',
 'home_formation',
 'away_formation'
]

df = df.loc[:, list_of_columns]
df.head()
# Out:
#           home         away       date    league part_of_competition  \
# 0  New England     San Jose  7/31/1996  1996 MLS      Regular Season
# 1       Dallas     Colorado  6/15/1996  1996 MLS      Regular Season
# 2     Colorado  D.C. United  8/29/1996  1996 MLS      Regular Season
# 3    LA Galaxy  New England   8/8/1996  1996 MLS      Regular Season
# 4  New England  D.C. United  7/20/1996  1996 MLS      Regular Season
#
#   game_status  home_score  away_score home_possessionPct away_possessionPct  \
# 0          FT           2           0                NaN                NaN
# 1          FT           1           1                NaN                NaN
# 2          FT           1           2                NaN                NaN
# 3          FT           1           0                NaN                NaN
# 4          FT           2           0                NaN                NaN
#
#    ... home_redCards away_redCards  home_offsides  away_offsides  \
# 0  ...           NaN           NaN            NaN            NaN
# 1  ...           NaN           NaN            NaN            NaN
# 2  ...           NaN           NaN            NaN            NaN
# 3  ...           NaN           NaN            NaN            NaN
# 4  ...           NaN           NaN            NaN            NaN
#
#    home_wonCorners  away_wonCorners  home_saves  away_saves  home_formation  \
# 0              NaN              NaN         NaN         NaN             NaN
# 1              NaN              NaN         NaN         NaN             NaN
# 2              NaN              NaN         NaN         NaN             NaN
# 3              NaN              NaN         NaN         NaN             NaN
# 4              NaN              NaN         NaN         NaN             NaN
#
#    away_formation
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 26 columns]

# %%
# dropping nas
df = df.dropna()

# %%
# unpacking shot summaries 
def shots(shot_summary):
    interm_string = shot_summary.strip(')')
    entries = interm_string.split('(')
    return int(entries[0])

def shots_on_goal(shot_summary):
    interm_string = shot_summary.strip(')')
    entries = interm_string.split('(')
    return int(entries[1])

df['home_shots'] = df['home_shotsSummary'].apply(shots)
df['home_shots_on_goal'] = df['home_shotsSummary'].apply(shots_on_goal)
df = df.drop('home_shotsSummary', axis=1)

df['away_shots'] = df['away_shotsSummary'].apply(shots)
df['away_shots_on_goal'] = df['away_shotsSummary'].apply(shots_on_goal)
df = df.drop('away_shotsSummary', axis=1)

df.columns
# Out:
# Index(['home', 'away', 'date', 'league', 'part_of_competition', 'game_status',
#        'home_score', 'away_score', 'home_possessionPct', 'away_possessionPct',
#        'home_foulsCommitted', 'away_foulsCommitted', 'home_yellowCards',
#        'away_yellowCards', 'home_redCards', 'away_redCards', 'home_offsides',
#        'away_offsides', 'home_wonCorners', 'away_wonCorners', 'home_saves',
#        'away_saves', 'home_formation', 'away_formation', 'home_shots',
#        'home_shots_on_goal', 'away_shots', 'away_shots_on_goal'],
#       dtype='object')

# %%
# Creating result column
def decide_victory(home, away):
    if home > away:
        return 'h'
    elif home < away:
        return 'a'
    else:
        return 'd'

f_decide_victory = np.vectorize(decide_victory)

df['result'] = f_decide_victory(df['home_score'], df['away_score'])

df.head()
# Out:
#                       home                    away                date  \
# 3264       Colorado Rapids        Columbus Crew SC  Saturday, March 10
# 3265   Vancouver Whitecaps         Montreal Impact  Saturday, March 10
# 3266             DC United    Sporting Kansas City  Saturday, March 10
# 3267             LA Galaxy          Real Salt Lake  Saturday, March 10
# 3268  San Jose Earthquakes  New England Revolution  Saturday, March 10
#
#                             league   part_of_competition game_status  \
# 3264  2012 USA Major League Soccer   Regular Season 2012          FT
# 3265  2012 USA Major League Soccer   Regular Season 2012          FT
# 3266  2012 USA Major League Soccer   Regular Season 2012          FT
# 3267  2012 USA Major League Soccer   Regular Season 2012          FT
# 3268  2012 USA Major League Soccer   Regular Season 2012          FT
#
#       home_score  away_score home_possessionPct away_possessionPct  ...  \
# 3264           2           0                53%                47%  ...
# 3265           2           0                50%                50%  ...
# 3266           0           1                43%                57%  ...
# 3267           1           3                49%                51%  ...
# 3268           1           0                52%                48%  ...
#
#       away_wonCorners  home_saves  away_saves  home_formation  away_formation  \
# 3264              4.0         3.0         3.0         4-2-3-1           4-5-1
# 3265              4.0         7.0         3.0         4-2-3-1           4-4-2
# 3266              5.0         7.0         1.0           4-4-2         4-2-3-1
# 3267              2.0         2.0         3.0           4-4-2       4-1-2-1-2
# 3268              3.0         1.0         0.0           4-5-1           4-4-2
#
#       home_shots  home_shots_on_goal  away_shots  away_shots_on_goal  result
# 3264          17                   5           5                   3       h
# 3265          11                   5          15                   7       h
# 3266           7                   1          17                   8       a
# 3267          17                   4          13                   4       a
# 3268           5                   1           6                   1       h
#
# [5 rows x 29 columns]

# %%
# Formatting the percentages columns 
def strip_perc_symbol(perc):
    return float(perc.strip('%'))

df['home_possessionPct'] = df['home_possessionPct'].apply(strip_perc_symbol)
df['away_possessionPct'] = df['away_possessionPct'].apply(strip_perc_symbol)

df.head()
# Out:
#                       home                    away                date  \
# 3264       Colorado Rapids        Columbus Crew SC  Saturday, March 10
# 3265   Vancouver Whitecaps         Montreal Impact  Saturday, March 10
# 3266             DC United    Sporting Kansas City  Saturday, March 10
# 3267             LA Galaxy          Real Salt Lake  Saturday, March 10
# 3268  San Jose Earthquakes  New England Revolution  Saturday, March 10
#
#                             league   part_of_competition game_status  \
# 3264  2012 USA Major League Soccer   Regular Season 2012          FT
# 3265  2012 USA Major League Soccer   Regular Season 2012          FT
# 3266  2012 USA Major League Soccer   Regular Season 2012          FT
# 3267  2012 USA Major League Soccer   Regular Season 2012          FT
# 3268  2012 USA Major League Soccer   Regular Season 2012          FT
#
#       home_score  away_score  home_possessionPct  away_possessionPct  ...  \
# 3264           2           0                53.0                47.0  ...
# 3265           2           0                50.0                50.0  ...
# 3266           0           1                43.0                57.0  ...
# 3267           1           3                49.0                51.0  ...
# 3268           1           0                52.0                48.0  ...
#
#       away_wonCorners  home_saves  away_saves  home_formation  away_formation  \
# 3264              4.0         3.0         3.0         4-2-3-1           4-5-1
# 3265              4.0         7.0         3.0         4-2-3-1           4-4-2
# 3266              5.0         7.0         1.0           4-4-2         4-2-3-1
# 3267              2.0         2.0         3.0           4-4-2       4-1-2-1-2
# 3268              3.0         1.0         0.0           4-5-1           4-4-2
#
#       home_shots  home_shots_on_goal  away_shots  away_shots_on_goal  result
# 3264          17                   5           5                   3       h
# 3265          11                   5          15                   7       h
# 3266           7                   1          17                   8       a
# 3267          17                   4          13                   4       a
# 3268           5                   1           6                   1       h
#
# [5 rows x 29 columns]

# %%
# Droppping one last column 
df = df.drop('game_status', axis=1)
df.columns
# Out:
# Index(['home', 'away', 'date', 'league', 'part_of_competition', 'home_score',
#        'away_score', 'home_possessionPct', 'away_possessionPct',
#        'home_foulsCommitted', 'away_foulsCommitted', 'home_yellowCards',
#        'away_yellowCards', 'home_redCards', 'away_redCards', 'home_offsides',
#        'away_offsides', 'home_wonCorners', 'away_wonCorners', 'home_saves',
#        'away_saves', 'home_formation', 'away_formation', 'home_shots',
#        'home_shots_on_goal', 'away_shots', 'away_shots_on_goal', 'result'],
#       dtype='object')

# %%
# Preparing data for machine learning algorithms
X = df.drop(['home_score', 'away_score', 'result'], axis=1)
y = df['result']

# %% [markdown]
# ## Random Forest Classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

X = pd.get_dummies(X)

Xtrain, Xtest, ytrain, ytest = train_test_split(X,y, random_state=0)
Xtrain2, Xval, ytrain2, yval = train_test_split(Xtest, ytest, random_state=0)

accuracies = []
for n in range(100):
    model = RandomForestClassifier(n_estimators=n+1)
    model.fit(Xtrain2, ytrain2)
    ypredval = model.predict(Xval)
    accuracies.append(metrics.accuracy_score(yval, ypredval))

plt.plot(range(1, 101), np.array(accuracies))

# %%
model = RandomForestClassifier(n_estimators=60, random_state=0)
model.fit(Xtrain, ytrain)
ypred = model.predict(Xtest)

print(metrics.classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            a       0.62      0.34      0.44       229
#            d       0.40      0.07      0.12       247
#            h       0.57      0.95      0.71       460
#
#     accuracy                           0.57       936
#    macro avg       0.53      0.45      0.42       936
# weighted avg       0.54      0.57      0.49       936

# %%
sns.heatmap(metrics.confusion_matrix(ytest, ypred).T, annot=True, fmt='d')
plt.xlabel('True Label')
plt.ylabel('Predicted Label')
# Out:
# Text(30.5, 0.5, 'Predicted Label')

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC 
from sklearn.pipeline import make_pipeline

svc = SVC(kernel='rbf', class_weight='balanced')
model = make_pipeline(svc)

from sklearn.model_selection import GridSearchCV

param_grid = {'svc__C':[1,5,10,50], 'svc__gamma':[0.0001, 0.0005, 0.001, 0.005]}

grid = GridSearchCV(model, param_grid)

grid.fit(Xtrain, ytrain)
print(grid.best_params_)
# Out:
# {'svc__C': 50, 'svc__gamma': 0.0005}

# %%
model = grid.best_estimator_

ypred = model.predict(Xtest)

print(metrics.classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            a       0.94      0.94      0.94       229
#            d       0.87      0.89      0.88       247
#            h       0.96      0.95      0.96       460
#
#     accuracy                           0.93       936
#    macro avg       0.93      0.93      0.93       936
# weighted avg       0.93      0.93      0.93       936

# %%
sns.heatmap(metrics.confusion_matrix(ytest, ypred).T, annot=True, fmt='d')
plt.xlabel('True Label')
plt.ylabel('Predicted Label')
# Out:
# Text(30.5, 0.5, 'Predicted Label')
